# %%
#clinical embeddings

# !python run_clinical_embedding.py \
 --excel_path "/content/drive/MyDrive/clinical.xlsx" \
 --output_dir "/content/drive/MyDrive/CLINICAL_EMBEDDINGS" \
 --patient_id_column "patient_id" \
 --embedding_dim 64
